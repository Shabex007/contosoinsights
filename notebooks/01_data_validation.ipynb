# %%
import pandas as pd

df = pd.read_parquet(
    "../data/processed/customer_ml_features.parquet"
)

df.head()
# Out:
#    customerkey       customer_name  age countryfull  cohort_year  \
# 0           15     Julian McGuigan   55   Australia         2021
# 1          180   Gabriel Bosanquet   65   Australia         2018
# 2          185  Gabrielle Castella   40   Australia         2019
# 3          243       Maya Atherton   66   Australia         2016
# 4          387    Tahlia Underwood   35   Australia         2018
#
#   first_purchase_date last_purchase_date dataset_max_order_date  recency_days  \
# 0          2021-03-08         2021-03-08             2024-04-20          1139
# 1          2018-07-28         2023-08-28             2024-04-20           236
# 2          2019-06-01         2019-06-01             2024-04-20          1785
# 3          2016-05-19         2016-05-19             2024-04-20          2893
# 4          2018-12-21         2023-11-16             2024-04-20           156
#
#    customer_tenure_days  ...  avg_products_per_order  \
# ...

# %%
df.shape
# Out:
# (49487, 35)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 49487 entries, 0 to 49486
# Data columns (total 35 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   customerkey                            49487 non-null  int64
#  1   customer_name                          49487 non-null  str
#  2   age                                    49487 non-null  int64
#  3   countryfull                            49487 non-null  str
#  4   cohort_year                            49487 non-null  int64
#  5   first_purchase_date                    49487 non-null  object
#  6   last_purchase_date                     49487 non-null  object
#  7   dataset_max_order_date                 49487 non-null  object
#  8   recency_days                           49487 non-null  int64
#  9   customer_tenure_days                   49487 non-null  int64
#  10  frequency                              49487 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# customerkey                              0
# customer_name                            0
# age                                      0
# countryfull                              0
# cohort_year                              0
# first_purchase_date                      0
# last_purchase_date                       0
# dataset_max_order_date                   0
# recency_days                             0
# customer_tenure_days                     0
# frequency                                0
# total_order_lines                        0
# total_quantity                           0
# unique_products_bought                   0
# unique_categories_bought                 0
# monetary_value                           0
# total_revenue                            0
# total_cost                               0
# total_gross_profit                       0
# gross_margin_pct                         0
# avg_order_value                          0
# max_order_value                          0
# ...

# %%
df.customerkey.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["is_churned_180d"].value_counts(normalize=True)
# Out:
# is_churned_180d
# 1    0.860327
# 0    0.139673
# Name: proportion, dtype: float64
